# %% [markdown]
# # 1. 데이터 모형
# * 데이터 모형(data model) : 데이터를 만들어내는 가상의 데이터 생성기
# * 데이터 모형이 갖추어야 할 조건
#     * 해당 데이터와 분포 특성이 같은 데이터를 만들 수 있어야 한다.
#         * 두 데이터 표본집합의 분포 특성이 완전히 같으면 같은 데이터라고 할 수 있다. 즉, 두 데이터 표본집합은 같은 데이터 생성기로부터 나온 것이다.
#     * 데이터의 생성과정이 수학적으로 기술될 수 있고 알고리즘에 의해 구현될 수 있어야 한다.
#         * 어떤 수학적인 방법으로 우리가 가진 데이터와 완전히 같은 분포 특성을 가지는 데이터를 만들 수 있다면 그 데이터의 생성기를 확보한 것이나 마찬가지다.

# %% [markdown]
# # 2. 확률변수
# * 수학적 정의 : 확률이 정의된 표본공간의 모든 표본을 실수인 숫자로 바꾸는 함수
# $$ 확률변수 $$
# $$ ω ∈ Ω →→→→→→→→ x ∈ R $$
# * X와 같이 대문자 알파벳으로 표기
# * 확률변수에 의해 할당된 실수는 x와 같이 소문자 알파벳으로 표기
#     * 경우에 따라 소문자 알파벳으로 확률변수를 표기하는 경우도 있다.
# $$ X(ω) = x(x ∈ R) $$

# %% [markdown]
# # 3. 이산확률변수
# * 이산확률변수(discrete random variable) : 확률변수값이 연속적이지 않고 떨어져(discrete) 있는 경우
# $$ X(주사위 눈금 1) = 1 $$
# $$ X(주사위 눈금 2) = 2 $$
# $$ X(주사위 눈금 3) = 3 $$
# $$ X(주사위 눈금 4) = 4 $$
# $$ X(주사위 눈금 5) = 5 $$
# $$ X(주사위 눈금 6) = 6 $$
# * 주의할 점
#     * 이산확률의 정의는 값의 이산성 (가능한 경우가 유한하다는 점은 아님)
#     * 이산 확률변수도 연속 확률변수처럼 가능한 값이 무한대의 경우의 수가 있을 수 있다.
#         * 예) 기하 분포는 양의 정수값을 가지는 이산 분포이지만 무한대의 양의 정수도 0이 아닌 확률을 가질 수 있다.

# %% [markdown]
# # 4. 연속확률변수
# * 연속확률변수(continuous random variable) : 연속적이고 무한대의 실수 표본값을 가지는 확률변수
# * 모든 표본이 실수로 변한다면 모든 사건은 단순구간사건의 조합으로 표시된다.
# * 즉, 확률이 어떻게 할당되었는가를 나타내는 정보인 확률분포를 수학적인 확률분포함수로 나타낼 수 있다는 뜻

# %% [markdown]
# # 5. 확률변수와 데이터
# * 확률변수를 실수인 데이터를 생성하는 데이터 생성기로 생각하면 된다.
# * 다만 확률분포함수라는 간결, 정확한 수학적 도구를 이용하여 확률이 정의되어 있다는 점
# * 실현(realization) 혹은 표본화(sampling) : 확률분포함수에 따라 표본공간의 표본이 현실 세계의 데이터로 선택되는 것
# * 표본화의 다른 의미 : 많은 수의 데이터 집합에서 일부 데이터만 선택하는 과정
#
# #### 확률변수와 실제 데이터의 관계
# * 확률변수로부터 데이터를 여러번 생성하는 경우 실제 데이터값은 매번 달라질 수 있지만 확률 모형 자체는 변하지 않는다.
# * 확률변수의 확률분포함수는 우리가 직접 관찰할 수 없다. 다만 확률변수에서 만들어지는 실제 데이터 값을 이용하여 확률분포함수가 이러한 것일 거라고 추정할 뿐이다.
# * 확률변수에서 만들어지는 실제 데이터의 값은 확률변수가 가진 특성을 반영하고 있다. 데이터의 갯수가 적을수록 확률변수가 가진 특징을 정확하게 표현하지 못하지만 데이터의 갯수가 증가하면 보다 정확하게 확률분포함수를 묘사할 수 있게 된다.

# %% [markdown]
# # 6. 확률변수를 사용한 데이터 분석
# * 확률변수를 사용한 데이터 분석 순서
#     1. 데이터를 확보한다.
#     2. 확보된 데이터를 어떤 확률변수의 표본으로 가정한다.
#     3. 데이터의 특성으로부터 확률변수의 특성을 추정한다.
#     4. 구해진 확률변수의 특성으로 해당 확률분포함수의 모양을 결정하고 모수를 추정한다.
#     5. 구해진 확률변수로부터 다음에 생성될 데이터나 데이터 특성을 예측한다.
